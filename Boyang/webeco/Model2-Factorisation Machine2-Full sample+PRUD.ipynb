# %%
import numpy as np
import pandas as pd
#import training setvalid_newfeature
Train_df = pd.read_csv('/project/Data/train_newfeature.csv')
#import validation set
Valid_df = pd.read_csv('/project/Data/valid_newfeature.csv')

# %%
Train_df_price = pd.read_csv('/project/Data/price.csv')

# %%
Train_df['payprice']= Train_df_price['payprice']

# %%
1793/244712
# Out:
# 0.007326980287031285

# %%
202/303925
# Out:
# 0.0006646376573167722

# %%
# columns of without click
cols=list(Train_df.columns)[1:-1]

# %%
Train_df.columns.get_values()
# Out:
# array(['click', 'slotwidth', 'slotheight', 'slotprice', 'android', 'ios',
#        'linux', 'mac', 'other', 'windows', 'chrome', 'firefox', 'ie',
#        'maxthon', 'opera', 'other.1', 'safari', 'sogou', 'theworld',
#        '10006', '10024', '10031', '10048', '10052', '10057', '10059',
#        '10063', '10067', '10074', '10075', '10076', '10077', '10079',
#        '10083', '10093', '10102', '10110', '10111', '10114', '10115',
#        '10116', '10117', '10118', '10120', '10123', '10125', '10126',
#        '10127', '10129', '10130', '10131', '10133', '10138', '10140',
#        '10142', '10145', '10146', '10147', '10148', '10149', '10684',
#        '11092', '11278', '11379', '11423', '11512', '11576', '11632',
#        '11680', '11724', '11944', '13042', '13403', '13496', '13678',
#        '13776', '13800', '13866', '13874', '14273', '15398', '16593',
#        '16617', '16661', '16706', '16751', '16753', 'hour_sin',
#        'hour_cos', 'city_per', 'region_per', 'weekday_0', 'weekday_1',
#        'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6',
#        'adexchange_1.0', 'adexchange_2.0', 'adexchange_3.0',
#        'adexchange_4.0', 'adexchange_nan', 'slotvisibility_0',
#        'slotvisibility_1', 'slotvisibility_2', 'slotvisibility_255',
#        'slotvisibility_FifthView', 'slotvisibility_FirstView',
#        'slotvisibility_FourthView', 'slotvisibility_Na',
#        'slotvisibility_OtherView', 'slotvisibility_SecondView',
#        'slotvisibility_ThirdView', 'slotformat_0', 'slotformat_1',
#        'slotformat_5', 'slotformat_Na', 'advertiser_1458',
#        'advertiser_2259', 'advertiser_2261', 'advertiser_2821',
#        'advertiser_2997', 'advertiser_3358', 'advertiser_3386',
#        'advertiser_3427', 'advertiser_3476', 'payprice'], dtype=object)

# %%
Train_df['slotheight']=Train_df['slotheight']/10
Train_df['slotwidth']=Train_df['slotwidth']/100
Train_df['slotprice']=Train_df['slotprice']/100

Valid_df['slotheight']=Valid_df['slotheight']/10
Valid_df['slotwidth']=Valid_df['slotwidth']/100
Valid_df['slotprice']=Valid_df['slotprice']/100

# %%
#train = Train_df
y_tr = Train_df['click']
X_tr = Train_df[cols]
y_te = Valid_df['click']
X_te = Valid_df[cols]

# %%
y_tr_p = Train_df['payprice']
y_te_p = df_valid['payprice']

# %%
X_te=X_te.values
X_tr=X_tr.values
y_te=y_te.values
y_tr=y_tr.values

# %%
y_tr_p = y_tr_p.values
y_te_p = y_te_p.values

# %%
import scipy.sparse as sp
# only CSR format supported
X_tr_sparse = sp.csr_matrix(X_tr)
X_te_sparse = sp.csr_matrix(X_te)

# %%
#! pip install tqdm

# %%
#23:33
#train Factorised Machine model
from tffm import TFFMClassifier
import tensorflow as tf
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score


model = TFFMClassifier(
    order=3, 
    rank=10, 
    optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
    n_epochs=30, 
    batch_size=1024,
    init_std=0.001,
    reg=0.01,
    input_type='sparse',
    seed=42
)

model.fit(X_tr_sparse, y_tr, show_progress=True)
# Out:
# 100%|██████████| 30/30 [45:03<00:00, 90.13s/epoch]

# %%
# regression!!!
from tffm import TFFMRegressor
from sklearn.metrics import mean_squared_error

model2 = TFFMRegressor(
    order=3, 
    rank=10, 
    optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
    n_epochs=30, 
    batch_size=1024,
    init_std=0.001,
    reg=0.01,
    input_type='sparse'
)
# translate Y from {0,1} to {-10, 10}
model2.fit(X_tr_sparse, y_tr_p, show_progress=True)
#model.destroy()
# Out:
#  60%|██████    | 18/30 [25:40<17:06, 85.58s/epoch]

# %%
valid_predictions = model.predict_proba(X_te_sparse)
valid_predictions_class = model.predict(X_te_sparse)
valid_predictions_price = model2.predict(X_te_sparse)

acc = accuracy_score(y_te, valid_predictions_class)
print('model: {}'.format(model.__str__()))
print("the accuracy is: {0:6f}".format(acc))
print ("the AUC for FM is: {0:6f}".format(roc_auc_score(y_te, valid_predictions[:,1])))
print("==================================")
print(' accuracy: {}'.format( accuracy_score(y_te_p, valid_predictions_price > 0)))
print('MSE: {}'.format(mean_squared_error(y_te_p, valid_predictions_price)))
# Out:
# /project/tffm-master/tffm/utils.py:195: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# model: TFFMClassifier()
# the accuracy is: 0.999368
# the AUC for FM is: 0.860693
# ==================================
#  accuracy: 0.0009574730607880234
# MSE: 2599.223291840396

# %%
"""model: TFFMClassifier()
the accuracy is: 0.999154
the AUC for FM is: 0.874338
==================================
 accuracy: 0.0009574730607880234
MSE: 2715.4566462513308"""
# Out:
# 'model: TFFMClassifier()\nthe accuracy is: 0.999154\nthe AUC for FM is: 0.874338\n==================================\n accuracy: 0.0009574730607880234\nMSE: 2715.4566462513308'

# %%
np.sqrt(mean_squared_error(y_te_p, valid_predictions_price))
# Out:
# 51.12058225232048

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
y_te_p.mean()
# Out:
# 78.23400509994242

# %%
valid_predictions_price.mean()
# Out:
# 76.25434

# %%
mean_absolute_percentage_error(y_te_p, valid_predictions_price)
# Out:
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in true_divide
# inf

# %%
valid_predictions_price
# Out:
# array([ 45.48623 ,  82.63118 ,  73.96106 , ..., 142.93533 ,  82.9575  ,
#         54.245533], dtype=float32)

# %%
df_valid.payprice
# Out:
# 0          23
# 1          75
# 2          65
# 3           6
# 4           5
# 5          22
# 6          31
# 7          20
# 8          58
# 9          55
# 10         88
# 11         55
# 12         49
# 13        110
# 14        160
# 15         16
# 16         50
# 17         76
# 18         89
# 19        136
# 20         55
# 21         50
# 22         64
# 23        129
# 24         20
# 25        166
# 26         88
# 27        221
# 28         69
# 29         70
#          ...
# 303895    185
# 303896     22
# 303897     86
# 303898    230
# 303899     76
# 303900     20
# 303901     27
# 303902    160
# 303903     77
# 303904    160
# 303905     20
# 303906     80
# 303907    265
# 303908     70
# 303909     50
# 303910     70
# 303911     93
# 303912     77
# 303913    100
# 303914     22
# 303915      5
# 303916     20
# 303917     17
# 303918     50
# 303919     64
# 303920     50
# 303921     41
# 303922    108
# 303923     50
# 303924     40
# Name: payprice, Length: 303925, dtype: int64

# %%
valid_predictions_price[0:60]
# Out:
# array([76.80698 , 78.25091 , 78.46629 , 77.30149 , 76.35184 , 78.650566,
#        77.718254, 75.43074 , 74.88015 , 76.353745, 75.13704 , 78.532974,
#        75.76261 , 77.35777 , 75.61342 , 72.355446, 74.74335 , 74.30819 ,
#        73.87895 , 78.96992 , 78.05844 , 76.59737 , 80.19076 , 77.24302 ,
#        80.54137 , 76.08204 , 76.667625, 77.77282 , 76.89774 , 77.29091 ,
#        78.652985, 77.94873 , 77.05325 , 71.1002  , 75.658035, 80.9769  ,
#        74.72383 , 81.22947 , 75.49059 , 78.04804 , 77.207535, 77.510704,
#        77.76675 , 77.623405, 77.24988 , 75.776566, 74.76866 , 77.516754,
#        76.54333 , 76.128105, 79.871544, 85.9287  , 73.04078 , 77.83713 ,
#        68.34403 , 77.25331 , 76.68454 , 79.13414 , 78.55276 , 78.8875  ],
#       dtype=float32)

# %%
def recalibrate(p,w):
    q = p/(p+(1-p)/w)
    return q

# %%
#valid_result['click_pred_per']=recalibrate(valid_result['click_pred_per'],0.1)
valid_result.head(20)
# Out:
#     click  click_pred_per  click_pred_class  click_pred_price         P_cut  \
# 0       0    8.073824e-06                 0         49.743359  1.623096e-07
# 1       0    1.511657e-05                 0         82.967194  1.821994e-07
# 2       0    1.075781e-06                 0         72.702225  1.479709e-08
# 3       0    6.874001e-07                 0         61.708523  1.113947e-08
# 4       0    1.298044e-05                 0         50.824638  2.553965e-07
# 5       0    1.281755e-04                 0         28.891647  4.436421e-06
# 6       0    1.756861e-04                 0         84.414116  2.081241e-06
# 7       0    2.228479e-04                 0         86.886627  2.564812e-06
# 8       0    1.351428e-04                 0         59.778442  2.260728e-06
# 9       0    7.047563e-06                 0         59.150475  1.191463e-07
# 10      0    3.953456e-04                 0         85.726624  4.611702e-06
# 11      0    2.703656e-05                 0         63.337646  4.268640e-07
# 12      0    2.519618e-05                 0         74.258278  3.393047e-07
# 13      0    2.899272e-04                 0         63.762768  4.546966e-06
# 14      0    9.997340e-05                 0        131.492569  7.602969e-07
# 15      0    1.818346e-05                 0         51.480827  3.532084e-07
# 16      0    3.376698e-06                 0         57.557030  5.866699e-08
# 17      0    3.500505e-05                 0         84.832664  4.126365e-07
# 18      0    7.539869e-05                 0        108.712921  6.935578e-07
# 19      0    4.254681e-05                 0        112.115143  3.794921e-07
#
#      rp
# 0    23
# 1    75
# 2    65
# 3     6
# 4     5
# 5    22
# 6    31
# 7    20
# 8    58
# 9    55
# 10   88
# 11   55
# 12   49
# 13  110
# 14  160
# 15   16
# 16   50
# 17   76
# 18   89
# 19  136

# %%
valid_result = pd.DataFrame(columns=['click', 'click_pred_per', 'click_pred_class'])  
valid_result['click']= Valid_df['click'].copy()
valid_result['click_pred_per'] = valid_predictions[:,1]
valid_result['click_pred_class'] = valid_predictions_class
#valid_result['click_pred_price'] = valid_predictions_price
valid_result.head(20)
# Out:
#     click  click_pred_per  click_pred_class
# 0       0    8.073824e-06                 0
# 1       0    1.511657e-05                 0
# 2       0    1.075781e-06                 0
# 3       0    6.874001e-07                 0
# 4       0    1.298044e-05                 0
# 5       0    1.281755e-04                 0
# 6       0    1.756861e-04                 0
# 7       0    2.228479e-04                 0
# 8       0    1.351428e-04                 0
# 9       0    7.047563e-06                 0
# 10      0    3.953456e-04                 0
# 11      0    2.703656e-05                 0
# 12      0    2.519618e-05                 0
# 13      0    2.899272e-04                 0
# 14      0    9.997340e-05                 0
# 15      0    1.818346e-05                 0
# 16      0    3.376698e-06                 0
# 17      0    3.500505e-05                 0
# 18      0    7.539869e-05                 0
# 19      0    4.254681e-05                 0

# %%
valid_result['P_cut']=valid_result['click_pred_per']/valid_result['click_pred_price']

# %%
valid_result.head(10)
# Out:
#    click  click_pred_per  click_pred_class
# 0      0    8.073824e-06                 0
# 1      0    1.511657e-05                 0
# 2      0    1.075781e-06                 0
# 3      0    6.874001e-07                 0
# 4      0    1.298044e-05                 0
# 5      0    1.281755e-04                 0
# 6      0    1.756861e-04                 0
# 7      0    2.228479e-04                 0
# 8      0    1.351428e-04                 0
# 9      0    7.047563e-06                 0

# %%
gg=valid_result.copy()

# %%
gg
# Out:
#         click  click_pred_per  click_pred_class  click_pred_price  \
# 0           0    1.289649e-05                 0         45.486229
# 1           0    1.233763e-05                 0         82.631180
# 2           0    1.730236e-05                 0         73.961060
# 3           0    2.250333e-05                 0         49.401405
# 4           0    2.504322e-04                 0         67.183739
# 5           0    3.017822e-04                 0         26.507147
# 6           0    2.119202e-04                 0        104.563683
# 7           0    3.128199e-04                 0         76.497818
# 8           0    2.826287e-04                 0         58.769058
# 9           0    1.128965e-05                 0         53.328194
# 10          0    3.263418e-04                 0         84.280807
# 11          0    3.038791e-05                 0         63.202682
# 12          0    5.351143e-05                 0         74.830894
# 13          0    4.612100e-04                 0         51.846046
# 14          0    1.802402e-04                 0        120.373840
# 15          0    2.838701e-05                 0         62.842781
# 16          0    2.197765e-04                 0         53.687061
# 17          0    4.212821e-05                 0         66.633286
# 18          0    3.689285e-06                 0         83.447540
# 19          0    1.694110e-04                 0         93.513023
# 20          0    2.911228e-04                 0         61.657562
# 21          0    6.278169e-04                 0         52.573841
# 22          0    1.074728e-04                 0         81.525932
# 23          0    8.447990e-05                 0         58.882317
# 24          0    4.536060e-04                 0         27.960514
# 25          0    4.270487e-04                 0         65.243912
# 26          0    6.894811e-06                 0         73.040985
# 27          0    3.733352e-04                 0         46.077301
# 28          0    9.384764e-05                 0         66.622665
# 29          0    4.364074e-04                 0         61.782524
# ...       ...             ...               ...               ...
# 303895      0    4.630681e-03                 0        120.963402
# 303896      0    6.066855e-06                 0         34.189766
# 303897      0    5.413025e-04                 0         30.838200
# 303898      0    3.646048e-04                 0        109.383583
# 303899      0    2.341147e-04                 0        104.846367
# 303900      0    2.445457e-04                 0         24.193810
# 303901      0    4.680719e-06                 0         71.982758
# 303902      0    1.768235e-04                 0         70.687675
# 303903      0    1.861861e-06                 0         70.821091
# 303904      0    5.088674e-04                 0         81.071709
# 303905      0    8.710315e-04                 0         29.034805
# 303906      0    7.479158e-05                 0        102.779129
# 303907      0    5.593003e-05                 0         76.297615
# 303908      0    8.454179e-05                 0         68.977814
# 303909      0    4.422281e-05                 0         49.445473
# 303910      0    1.426793e-04                 0         73.728607
# 303911      0    4.371150e-05                 0         60.611679
# 303912      0    2.162369e-04                 0         82.183617
# 303913      0    3.206562e-04                 0         85.229797
# 303914      0    3.067465e-06                 0         32.122211
# 303915      0    5.625450e-04                 0         55.047359
# 303916      0    8.219535e-04                 0         27.841217
# 303917      0    3.150259e-06                 0         79.121483
# 303918      0    3.839391e-04                 0         49.503658
# 303919      0    9.461367e-05                 0         49.487724
# 303920      0    1.028053e-04                 0         54.245323
# 303921      0    3.629404e-08                 0         59.301987
# 303922      0    8.895540e-04                 0        142.935333
# 303923      0    3.404530e-06                 0         82.957497
# 303924      0    4.503978e-04                 0         54.245533
#
#                P_cut  win   rp
# 0       2.835251e-07    0   23
# 1       1.493096e-07    0   75
# 2       2.339387e-07    0   65
# 3       4.555201e-07    0    6
# 4       3.727572e-06    0    5
# 5       1.138494e-05    1   22
# 6       2.026710e-06    0   31
# 7       4.089266e-06    0   20
# 8       4.809141e-06    0   58
# 9       2.117014e-07    0   55
# 10      3.872078e-06    0   88
# 11      4.808010e-07    0   55
# 12      7.150981e-07    0   49
# 13      8.895761e-06    0  110
# 14      1.497337e-06    0  160
# 15      4.517147e-07    0   16
# 16      4.093658e-06    0   50
# 17      6.322397e-07    0   76
# 18      4.421084e-08    0   89
# 19      1.811630e-06    0  136
# 20      4.721608e-06    0   55
# 21      1.194162e-05    1   50
# 22      1.318265e-06    0   64
# 23      1.434725e-06    0  129
# 24      1.622309e-05    1   20
# 25      6.545419e-06    0  166
# 26      9.439647e-08    0   88
# 27      8.102366e-06    0  221
# 28      1.408644e-06    0   69
# 29      7.063606e-06    0   70
# ...              ...  ...  ...
# 303895  3.828167e-05    0  185
# 303896  1.774465e-07    0   22
# 303897  1.755299e-05    0   86
# 303898  3.333268e-06    0  230
# 303899  2.232931e-06    0   76
# 303900  1.010778e-05    1   20
# 303901  6.502556e-08    0   27
# 303902  2.501476e-06    0  160
# 303903  2.628964e-08    0   77
# 303904  6.276756e-06    0  160
# 303905  2.999956e-05    1   20
# 303906  7.276923e-07    0   80
# 303907  7.330509e-07    0  265
# 303908  1.225637e-06    0   70
# 303909  8.943754e-07    0   50
# 303910  1.935195e-06    0   70
# 303911  7.211729e-07    0   93
# 303912  2.631144e-06    0   77
# 303913  3.762255e-06    0  100
# 303914  9.549360e-08    0   22
# 303915  1.021929e-05    1    5
# 303916  2.952290e-05    1   20
# 303917  3.981547e-08    0   17
# 303918  7.755772e-06    0   50
# 303919  1.911861e-06    0   64
# 303920  1.895192e-06    0   50
# 303921  6.120206e-10    0   41
# 303922  6.223471e-06    1  108
# 303923  4.103945e-08    0   50
# 303924  8.302947e-06    1   40
#
# [303925 rows x 7 columns]

# %%
valid_result['rp']=df_valid['payprice']

# %%
if gg['rp']>gg['win']:
    gg['ww']=5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-325570fb0f5f> in <module>()
# ----> 1 if gg['rp']>gg['win']:
#       2     gg['ww']=5
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
for i in valid_result.index:
    if valid_result.at[i,'click_pred_price']<0:
        valid_result.at[i,'click_pred_price']=1

# %%
valid_result[valid_result['click_pred_price']<0]
# Out:
# Empty DataFrame
# Columns: [click, click_pred_per, click_pred_class, click_pred_price, P_cut]
# Index: []

# %%
import math
def clicksum1(pc,test):
    final_price=[]
    total_budget=6500000
    current_budget=total_budget
    
    TR = test.copy()
    TR['final_price']=0
    TR['jud']=0
    for i in TR.index:
        if TR.at[i,'P_cut'] >= pc:
            tmp = math.ceil(TR.at[i,'click_pred_price'])
            if tmp <= current_budget:
                current_budget = current_budget - tmp
                TR.at[i,'final_price']=tmp
                if TR.at[i,'final_price']>=TR.at[i,'rp']:
                    TR.at[i,'jud']=1

                i=i+1
            else:
                #TR.at[i,'final_price']=current_budget
                #current_budget=0
                ##print("tmp is ", tmp)
                break
    #print("hahha",TR['final_price'].sum())  
    aa=TR[TR['jud']==1]

    click =aa['click'].sum()
    
    Imp=aa['click'].count()
    CTR= Clk/Imp
    Spd = total_budget-current_budget
    CPM = 1000*Spd/Imp
    eCPC = Spd/Clk
    return click,Imp,CTR,Spd,CPM,eCPC #, current_budget

# %%
valid_result['P_cut'].describe()
# Out:
# count    3.039250e+05
# mean     8.925228e-06
# std      1.375963e-04
# min      1.449072e-21
# 25%      5.444901e-07
# 50%      2.082289e-06
# 75%      6.298397e-06
# max      2.567869e-02
# Name: P_cut, dtype: float64

# %%
valid_result['P_cut'].min()
# Out:
# 1.4490717628655078e-21

# %%
for pc in [4.8e-6,5e-6,5.4e-6]:
    a=clicksum1(pc,valid_result)
    print(a)
# Out:
# (85, 59689, 0.0004188376417765417, 6499999, 108897.77010839518, 259999.96)
# (86, 59431, 0.0004206558866584779, 6445472, 108453.02956369572, 257818.88)
# (84, 56090, 0.0004457122481725798, 6031638, 107534.99732572651, 241265.52)

# %%
valid_result['new_price']

# %%
valid_result['P_cut'].quantile(0.6945)
# Out:
# 4.9771294593743254e-06

# %%
Test_df = pd.read_csv('/Users/weisihan/Downloads/we_data/mytestset.csv')

# %%
test_result['P_cut'].quantile(0.5)
# Out:
# 2.1072625776133453e-06

# %%
valid_result.head()
# Out:
#    click  click_pred_per  click_pred_class  click_pred_price         P_cut
# 0      0        0.000013                 0         45.486229  2.835251e-07
# 1      0        0.000012                 0         82.631180  1.493096e-07
# 2      0        0.000017                 0         73.961060  2.339387e-07
# 3      0        0.000023                 0         49.401405  4.555201e-07
# 4      0        0.000250                 0         67.183739  3.727572e-06

# %%
bb.final_price.sum()
# Out:
# 6421041

# %%
def agree_to_flag(click_pred_per):
    if click_pred_per >=0.5:
        return 1
    else:
        return 0
valid_result['click_pred_class'] = valid_result['click_pred_per'].map(agree_to_flag)

# %%
def clicksum2(test):
    TR = test.copy()
    TR['final_price']=0
    for i in TR.index:
        if TR.at[i,'P_cut'] >= 5.02e-6 :
            TR.at[i,'final_price']=math.ceil(TR.at[i,'click_pred_price'])
    return TR

# %%
bb=clicksum2(valid_result)

# %%
bb.final_price.sum()
# Out:
# 6421041

# %%
total_budget=6250
Clk = valid_result['click_pred_class'].sum()
Imp = valid_result['click_pred_class'].count()
CTR= Clk/Imp
Spd = total_budget 
CPM = 1000*Spd/Imp
eCPC = Spd/Clk

# %%
Clk
# Out:
# 25

# %%
def Prob3(Train_df):
    payprice=list(df_valid.payprice)
    Train_Const_summ = pd.DataFrame({'Clicks':'', 'Spend':'', 'CTR':'', 'CPM':'', 'eCPC':''}, index=[0])
    
    #if count_break = 5 break
    count_break = 0
    
    current_budget = 6250000
    Train_df['win'] = 0 #initialize win label
    bidprices = bb['final_price']
    #start biding...
    for i in Train_df.index:
        current_bidprice = bidprices[i]
        #consider budget
        if current_budget <= current_bidprice:              
            #count lack budget times
            count_break = count_break + 1
#             print('lack of budget!',"current_budget:",current_budget,";current_bidprice:",current_bidprice,';count_break:',count_break)
            if count_break > 5:
                break  
            #reset bidprice
            current_bidprice = current_budget
        else:
            count_break = 0
            

        #Winning criterion:
        current_payprice = payprice[i]
        if current_bidprice > current_payprice:
            Train_df.at[i, 'win'] = int(1)
            current_budget = current_budget - current_payprice
        else:
            Train_df.at[i, 'win'] = int(0)

    #biding end        
    
    Train_df_new = Train_df[Train_df['win']!=0]
    #wintimes,_ = Train_df_new.shape
    #print('wintimes:',wintimes)
    #print('current_budget',current_budget)

    
#     #commented in for
    Clk = Train_df_new['click'].sum()
    Imp = Train_df_new['click'].count()
    CTR= Clk/Imp
    Spd = total_budget - current_budget
    CPM = 1000*Spd/Imp
    eCPC = Spd/Clk
    
    Train_Const_summ.loc[0,'Clicks']=Clk
    Train_Const_summ.loc[0,'Spend']=Spd
    Train_Const_summ.loc[0,'CTR']=CTR
    Train_Const_summ.loc[0,'CPM']=CPM
    Train_Const_summ.loc[0,'eCPC']=eCPC

    print(Train_Const_summ)
    
        
    return Train_df,current_budget

# %%
a,d=Prob3(valid_result)
# Out:
#        CPM         CTR Clicks     Spend     eCPC
# 0 -69312.3  0.00133783     77  -3989341 -51809.6

# %%
aa=valid_result[valid_result['click']==1]

# %%
aa
# Out:
#         click  click_pred_per  click_pred_class  click_pred_price     P_cut  \
# 891         1        0.446580                 0         70.445351  0.006339
# 1702        1        0.075672                 0         60.575275  0.001249
# 2136        1        0.302027                 0        131.935745  0.002289
# 2292        1        0.000564                 0         58.045322  0.000010
# 3061        1        0.007934                 0         40.920021  0.000194
# 3253        1        0.666469                 1         71.835892  0.009278
# 5834        1        0.001383                 0         61.392906  0.000023
# 8447        1        0.000448                 0         78.211914  0.000006
# 11612       1        0.081864                 0         84.875557  0.000965
# 12233       1        0.002359                 0        103.336655  0.000023
# 13226       1        0.006069                 0         43.951820  0.000138
# 14760       1        0.001292                 0         67.101738  0.000019
# 18603       1        0.366576                 0         77.672180  0.004720
# 18705       1        0.008146                 0         55.685318  0.000146
# 27357       1        0.038059                 0         81.915733  0.000465
# 27456       1        0.000365                 0         67.710266  0.000005
# 29027       1        0.003018                 0         37.355076  0.000081
# 29442       1        0.000376                 0        113.084000  0.000003
# 30837       1        0.412171                 0         62.430489  0.006602
# 33097       1        0.000070                 0         64.074577  0.000001
# 36216       1        0.000334                 0         42.356991  0.000008
# 38982       1        0.001553                 0        172.216003  0.000009
# 42362       1        0.001885                 0         60.776878  0.000031
# 43266       1        0.005786                 0        165.173508  0.000035
# 43394       1        0.030130                 0         72.088875  0.000418
# 44921       1        0.000325                 0         35.082935  0.000009
# 45288       1        0.004811                 0         84.856598  0.000057
# 45965       1        0.666915                 1         80.332314  0.008302
# 45969       1        0.010813                 0        128.190704  0.000084
# 46461       1        0.002608                 0         66.187561  0.000039
# ...       ...             ...               ...               ...       ...
# 263502      1        0.007545                 0         41.613838  0.000181
# 266153      1        0.001115                 0        162.052567  0.000007
# 267024      1        0.000419                 0        145.837952  0.000003
# 268555      1        0.174879                 0         73.226601  0.002388
# 269133      1        0.000133                 0         36.807674  0.000004
# 271411      1        0.312383                 0         60.055786  0.005202
# 273501      1        0.402116                 0        102.206909  0.003934
# 279522      1        0.001225                 0         63.412582  0.000019
# 281226      1        0.220765                 0         59.128052  0.003734
# 283143      1        0.000915                 0        167.406937  0.000005
# 283810      1        0.046099                 0         89.762985  0.000514
# 285173      1        0.000330                 0         56.541183  0.000006
# 288719      1        0.000183                 0         53.669838  0.000003
# 289278      1        0.001798                 0         40.277237  0.000045
# 289891      1        0.153858                 0         37.153931  0.004141
# 290176      1        0.007327                 0         42.511108  0.000172
# 290888      1        0.000131                 0         65.221169  0.000002
# 291007      1        0.000264                 0         59.396503  0.000004
# 291533      1        0.000583                 0        115.799896  0.000005
# 291753      1        0.320492                 0         71.229546  0.004499
# 292852      1        0.000696                 0         74.546806  0.000009
# 294265      1        0.000689                 0         80.723198  0.000009
# 295528      1        0.049152                 0         69.277061  0.000709
# 297442      1        0.000296                 0         67.678780  0.000004
# 298212      1        0.000729                 0         80.883041  0.000009
# 298221      1        0.000547                 0         81.340698  0.000007
# 300268      1        0.000670                 0         74.472679  0.000009
# 301484      1        0.000689                 0         94.494194  0.000007
# 303045      1        0.000116                 0         49.751633  0.000002
# 303285      1        0.007700                 0         76.408264  0.000101
#
#         win
# 891       0
# 1702      0
# 2136      0
# 2292      0
# 3061      0
# 3253      0
# 5834      0
# 8447      0
# 11612     0
# 12233     0
# 13226     0
# 14760     0
# 18603     0
# 18705     0
# 27357     0
# 27456     0
# 29027     0
# 29442     0
# 30837     0
# 33097     0
# 36216     0
# 38982     0
# 42362     0
# 43266     0
# 43394     0
# 44921     0
# 45288     0
# 45965     0
# 45969     0
# 46461     0
# ...     ...
# 263502    0
# 266153    0
# 267024    0
# 268555    0
# 269133    0
# 271411    0
# 273501    0
# 279522    0
# 281226    0
# 283143    0
# 283810    0
# 285173    0
# 288719    0
# 289278    0
# 289891    0
# 290176    0
# 290888    0
# 291007    0
# 291533    0
# 291753    0
# 292852    0
# 294265    0
# 295528    0
# 297442    0
# 298212    0
# 298221    0
# 300268    0
# 301484    0
# 303045    0
# 303285    0
#
# [202 rows x 6 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix


y_test = valid_result['click']
y_pred_class = valid_result['click_pred_class']

print(confusion_matrix(y_test, y_pred_class))

confusion = confusion_matrix(y_test, y_pred_class)
TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
print ("TP:", TP)
print ("TN:", TN)
print ("FP:", FP)
print ("FN:", FN)

#准确率、识别率（Classification Accuracy）：分类器正确分类的比例
#print ((TP+TN) / float(TP+TN+FN+FP))
print ("Accuracy: %.6f%%" % (accuracy_score(y_test, y_pred_class)* 100.0) )

#灵敏性（Sensitivity），也称为真正例识别率、召回率（Recall）：正确识别的正例数据在实际正例数据中的百分比
#print (TP / float(TP+FN))
#recall = metrics.recall_score(y_test, y_pred_class)
print ("Recall: %.6f%%" % (recall_score(y_test, y_pred_class)* 100.0))

#特效性（Specificity），也称为真负例率：正确识别的负例数据在实际负例数据中的百分比
print ("Specificity: %.6f%%" % (TN / float(TN+FP)* 100.0))

#假阳率（False Positive Rate）：实际值是负例数据，预测错误的百分比
#print (FP / float(TN+FP))
specificity = TN / float(TN+FP)
print ("False Positive Rate: %.6f%%" %((1 - specificity)*100.0))

#精度（Precision）：看做精确性的度量，即标记为正类的数据实际为正例的百分比
#print (TP / float(TP+FP))
precision = precision_score(y_test, y_pred_class)
print ("Precision: %.6f%%" %(precision*100.0))

#F1（平衡F分数）：精确率和召回率的调和平均数
#print (TP / float(TP+FP))
f1 = f1_score(y_test, y_pred_class)
print ("F1 score: %.6f%%" %(f1*100.0))
# Out:
# [[303612    111]
#  [   146     56]]
# TP: 56
# TN: 303612
# FP: 111
# FN: 146
# Accuracy: 99.915440%
# Recall: 27.722772%
# Specificity: 99.963454%
# False Positive Rate: 0.036546%
# Precision: 33.532934%
# F1 score: 30.352304%

# %%
# allow plots to appear in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt


# IMPORTANT: first argument is true values, second argument is predicted probabilities
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
def plot_ROC_curve(data, prediction):
    """
    Function to plot the ROC curve with AUC.
    """

    # Compute fpr, tpr, thresholds and roc auc
    fpr, tpr, thresholds = roc_curve(data, prediction)
    roc_auc = roc_auc_score(data, prediction)

    # Plot ROC curve
    plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
    #plt.plot(fpr, tpr, label='Logistic Regression (area = %0.3f)' % logit_roc_auc)
    plt.plot([0, 1], [0, 1], 'r--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate or (1 - Specifity)')
    plt.ylabel('True Positive Rate or (Sensitivity)')
    plt.title('ROC curve for CTR')
    plt.grid(True)
    plt.legend(loc="lower right")
    
    return

# %%
plot_ROC_curve(valid_result['click'], valid_result['click_pred_per'])
#xgboost的auc
print ("the AUC for FM is: {0:6f}".format(roc_auc_score(valid_result['click'], valid_result['click_pred_per'])))
# Out:
# the AUC for FM is: 0.875950

# %%
#Find Base Bid
#! pip install mpld3
# Out:
# Collecting mpld3
# Installing collected packages: mpld3
# Successfully installed mpld3-0.3

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import mpld3
import numpy as np

# %%
df_valid = pd.read_csv("/project/Data/validation.csv")

# %%
# parameters
total_budget = 6250000
payprice = df_valid['payprice'].as_matrix()
Train_df_qr = df_valid.copy()
avgCTR = 1793/2430981 #train set
#tuning...

# %%
def generate_bidprice(base_bid, test_predictions):
    avgCTR = 1793/2430981#train set
    bidprices = base_bid*test_predictions/avgCTR
    return bidprices

# %%
def Prob3(Train_df,payprice,base_bid,test_predictions):
    Train_Const_summ = pd.DataFrame({'Clicks':'', 'Spend':'', 'CTR':'', 'CPM':'', 'eCPC':''}, index=[0])
    
    #if count_break = 5 break
    count_break = 0
    
    current_budget = total_budget
    Train_df['win'] = 0 #initialize win label
    bidprices =generate_bidprice(base_bid, test_predictions)
    #start biding...
    for i in Train_df.index:
        current_bidprice = bidprices[i]
        #consider budget
        if current_budget <= current_bidprice:              
            #count lack budget times
            count_break = count_break + 1
#             print('lack of budget!',"current_budget:",current_budget,";current_bidprice:",current_bidprice,';count_break:',count_break)
            if count_break > 5:
                break  
            #reset bidprice
            current_bidprice = current_budget
        else:
            count_break = 0
            

        #Winning criterion:
        current_payprice = payprice[i]
        if current_bidprice > current_payprice:
            Train_df.at[i, 'win'] = int(1)
            current_budget = current_budget - current_payprice
        else:
            Train_df.at[i, 'win'] = int(0)

    #biding end        
    
    Train_df_new = Train_df[Train_df['win']!=0]
    #wintimes,_ = Train_df_new.shape
    #print('wintimes:',wintimes)
    #print('current_budget',current_budget)

    
#     #commented in for
    Clk = Train_df_new['click'].sum()
    Imp = Train_df_new['click'].count()
    CTR= Clk/Imp
    Spd = total_budget - current_budget
    CPM = 1000*Spd/Imp
    eCPC = Spd/Clk
    
    Train_Const_summ.loc[0,'Clicks']=Clk
    Train_Const_summ.loc[0,'Spend']=Spd
    Train_Const_summ.loc[0,'CTR']=CTR
    Train_Const_summ.loc[0,'CPM']=CPM
    Train_Const_summ.loc[0,'eCPC']=eCPC

    print(Train_Const_summ)
    
        
    return Train_df,current_budget

# %%
def calculate_click(base_bid,Train_df,payprice,test_predictions):
#     print('base_bid:',base_bid)
    result_df,current_budget = Prob3(Train_df,payprice,base_bid,test_predictions)
#     print('current_budget:',current_budget)
    Train_df_new = result_df[result_df['win']!=0]
    wintimes,_ = Train_df_new.shape
#     print('wintimes:',wintimes)
#     print('----------------')
    Clk = Train_df_new['click'].sum()    
    return Clk

# %%
#test range
base_bids = np.arange(255,256,1)#区间可以适当左右调整一下，但大概就是这个范围
count = 0
maxClks = []

# %%
count = count + 1
print(str(count)+" valid result is being test...")
test_predictions=valid_result['click_pred_per']
Clks = [calculate_click(base_bid,Train_df_qr,payprice,test_predictions) for base_bid in base_bids]
print("max click@",Clks.index(max(Clks)),"base_bid=",base_bids[Clks.index(max(Clks))],"click =",max(Clks))
maxClks.append(max(Clks))
#     fig = plt.figure()
#     plt.plot(base_bids,Clks)
#     mpld3.display(fig)
# Out:
# 1 valid result is being test...
#        CPM         CTR Clicks    Spend     eCPC
# 0  58112.5  0.00147838    159  6249997  39308.2
# max click@ 0 base_bid= 255 click = 159

# %%
valid_result.to_csv('fmv.csv', encoding='utf-8', index=False)

# %%
def clicksum2(test):
    TR = test.copy()
    TR['final_price']=0
    for i in TR.index:
        if TR.at[i,'P_cut'] >= 2.1072625776133453e-06: 
            TR.at[i,'final_price']=math.ceil(TR.at[i,'click_pred_price'])+5
    return TR

# %% [markdown]
# #####

# %% [markdown]
# ## TEST

# %%
Test_df = pd.read_csv("/project/Data/mytestset.csv")
Group=  pd.read_csv('/project/Data/Group_xx.csv')

# %%
Test_df = Test_df[['slotwidth', 'slotheight', 'slotprice', 'android', 'ios',
       'linux', 'mac', 'other', 'windows', 'chrome', 'firefox', 'ie',
       'maxthon', 'opera', 'other.1', 'safari', 'sogou', 'theworld',
       '10006', '10024', '10031', '10048', '10052', '10057', '10059',
       '10063', '10067', '10074', '10075', '10076', '10077', '10079',
       '10083', '10093', '10102', '10110', '10111', '10114', '10115',
       '10116', '10117', '10118', '10120', '10123', '10125', '10126',
       '10127', '10129', '10130', '10131', '10133', '10138', '10140',
       '10142', '10145', '10146', '10147', '10148', '10149', '10684',
       '11092', '11278', '11379', '11423', '11512', '11576', '11632',
       '11680', '11724', '11944', '13042', '13403', '13496', '13678',
       '13776', '13800', '13866', '13874', '14273', '15398', '16593',
       '16617', '16661', '16706', '16751', '16753', 'hour_sin', 'hour_cos',
       'city_per', 'region_per', 'weekday_0', 'weekday_1', 'weekday_2',
       'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6',
       'adexchange_1.0', 'adexchange_2.0', 'adexchange_3.0',
       'adexchange_4.0', 'adexchange_nan', 'slotvisibility_0',
       'slotvisibility_1', 'slotvisibility_2', 'slotvisibility_255',
       'slotvisibility_FifthView', 'slotvisibility_FirstView',
       'slotvisibility_FourthView', 'slotvisibility_Na',
       'slotvisibility_OtherView', 'slotvisibility_SecondView',
       'slotvisibility_ThirdView', 'slotformat_0', 'slotformat_1',
       'slotformat_5', 'slotformat_Na', 'advertiser_1458',
       'advertiser_2259', 'advertiser_2261', 'advertiser_2821',
       'advertiser_2997', 'advertiser_3358', 'advertiser_3386',
       'advertiser_3427', 'advertiser_3476']]

# %%
Test_df['slotheight']=Test_df['slotheight']/10
Test_df['slotwidth']=Test_df['slotwidth']/100
Test_df['slotprice']=Test_df['slotprice']/100

# %%
test_x = Test_df
test_x=test_x.values
X_tr_sparse = sp.csr_matrix(test_x)

test_predictions = model.predict_proba(X_tr_sparse)
test_predictions_class = model.predict(X_tr_sparse)
#test_predictions_price = model2.predict(X_tr_sparse)
# Out:
# /project/tffm-master/tffm/utils.py:195: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))

# %%
test_reslut=[]

# %%
test_result = pd.DataFrame(columns=['click', 'click_pred_per', 'click_pred_class'])  
#test_result['click']= Valid_df['click'].copy()
test_result['click_pred_per'] = test_predictions[:,1]
test_result['click_pred_class'] = test_predictions_class
#test_result['click_pred_price'] = test_predictions_price
test_result.head()
# Out:
#   click  click_pred_per  click_pred_class
# 0   NaN        0.000138                 0
# 1   NaN        0.002382                 0
# 2   NaN        0.000004                 0
# 3   NaN        0.000047                 0
# 4   NaN        0.001101                 0

# %%
#test_result['click_pred_per']=recalibrate(test_result['click_pred_per'],0.1)

# %%
test_result.head(20)
# Out:
#    click  click_pred_per  click_pred_class
# 0    NaN        0.000138                 0
# 1    NaN        0.002382                 0
# 2    NaN        0.000004                 0
# 3    NaN        0.000047                 0
# 4    NaN        0.001101                 0
# 5    NaN        0.000005                 0
# 6    NaN        0.000054                 0
# 7    NaN        0.001214                 0
# 8    NaN        0.000050                 0
# 9    NaN        0.000490                 0
# 10   NaN        0.000100                 0
# 11   NaN        0.002393                 0
# 12   NaN        0.000181                 0
# 13   NaN        0.000028                 0
# 14   NaN        0.000200                 0
# 15   NaN        0.000093                 0
# 16   NaN        0.000060                 0
# 17   NaN        0.000055                 0
# 18   NaN        0.000447                 0
# 19   NaN        0.000284                 0

# %%
test_result.to_csv('fm.csv', encoding='utf-8', index=False)

# %%
test_result[test_result['click_pred_price']<0]=1

# %%
test_result['P_cut']=test_result['click_pred_per']/test_result['click_pred_price']
test_result.head()
# Out:
#   click  click_pred_per  click_pred_class  click_pred_price     P_cut
# 0   NaN        0.000565                 0         42.773262  0.000013
# 1   NaN        0.002101                 0         38.205078  0.000055
# 2   NaN        0.000333                 0         74.266556  0.000004
# 3   NaN        0.000066                 0         52.663895  0.000001
# 4   NaN        0.001091                 0         69.880096  0.000016

# %%
def clicksum2(test):
    TR = test.copy()
    TR['final_price']=0
    for i in TR.index:
        if TR.at[i,'P_cut'] >= 2.1072625776133453e-06: 
            TR.at[i,'final_price']=math.ceil(TR.at[i,'click_pred_price'])+5
    return TR

# %%
test_final=clicksum2(test_result)

# %%
test_final.head()
# Out:
#   click  click_pred_per  click_pred_class  click_pred_price     P_cut  \
# 0   NaN        0.000565                 0         42.773262  0.000013
# 1   NaN        0.002101                 0         38.205078  0.000055
# 2   NaN        0.000333                 0         74.266556  0.000004
# 3   NaN        0.000066                 0         52.663895  0.000001
# 4   NaN        0.001091                 0         69.880096  0.000016
#
#    final_price
# 0           48
# 1           44
# 2           80
# 3            0
# 4           75

# %%
test_final.head()
# Out:
#   click  click_pred_per  click_pred_class  click_pred_price     P_cut  \
# 0   NaN        0.000565                 0         42.773262  0.000013
# 1   NaN        0.002101                 0         38.205078  0.000055
# 2   NaN        0.000333                 0         74.266556  0.000004
# 3   NaN        0.000066                 0         52.663895  0.000001
# 4   NaN        0.001091                 0         69.880096  0.000016
#
#    final_price
# 0           48
# 1           44
# 2            0
# 3            0
# 4           75

# %%
test_final.sum()
# Out:
# click               3.400000e+01
# click_pred_per      2.273873e+02
# click_pred_class    1.970000e+02
# click_pred_price    2.302837e+07
# P_cut               3.672705e+01
# final_price         6.944936e+06
# dtype: float64

# %%
Group['bidprice']=test_final['final_price']

# %%
Group.head()
# Out:
#                                       bidid  bidprice
# 0  366c563de7d90feb9d4dab53e795a93fb3157387        48
# 1  29167d4caa719788b5a342dbaa25151d53121f80        44
# 2  ff8bc3f4d44a3ea60c5f3a3a8fbe7cd98fb2966e        80
# 3  844c2da00d45315f20b748ec131c26ee99a7cbc7         0
# 4  c6017f0ad0c44d7d0c9b62583ea863f28941c0ca        75

# %%
Group.head()
# Out:
#                                       bidid    bidprice
# 0  366c563de7d90feb9d4dab53e795a93fb3157387   53.841645
# 1  29167d4caa719788b5a342dbaa25151d53121f80  534.687231
# 2  ff8bc3f4d44a3ea60c5f3a3a8fbe7cd98fb2966e   24.625266
# 3  844c2da00d45315f20b748ec131c26ee99a7cbc7    5.600366
# 4  c6017f0ad0c44d7d0c9b62583ea863f28941c0ca  241.749085

# %%
Group.to_csv('Groupdef_6.csv', encoding='utf-8', index=False)

# %%
df_valid = pd.read_csv("/Users/weisihan/Downloads/we_data/validation.csv")

# %%
#clicks = len(train[train.click==1])
#impression = len(train[train.bidprice>train.payprice])
aCTR=1793/2430981
aCTR
# Out:
# 0.0007375623256619447

# %%
def evaluate(bidprice):
    budget=6250000
    impression=0
    click=0
    for row in range(0,df_valid.shape[0]):
        if budget<df_valid.payprice[row]:
            continue
        if bidprice.iloc[row,0]>df_valid.payprice[row]:
            budget=budget-df_valid.payprice[row]
            impression=impression+1
            if df_valid.click[row]==1:
                click=click+1
    return click

# %%
def bid_linear(basebid, pred_CTR,avg_CTR):
    bid = np.zeros((df_valid.shape[0], 1))
    for i in range (0,df_valid.shape[0]):
        bid[i,0] = basebid*xx.iloc[i]/avg_CTR
    bid = pd.DataFrame(bid)
    return bid

# %%
xx=test_result['click_pred_per'].copy()

# %%
base_bids = np.arange(10,200,10)
for counter in base_bids:
    base_bid=counter
    bidprice=bid_linear(base_bid, xx, aCTR)
    print('basebid ', base_bid, ' click ', evaluate(bidprice))
# Out:
# basebid  10  click  82
# basebid  20  click  95
# basebid  30  click  103
# basebid  40  click  110
# basebid  50  click  117
# basebid  60  click  121
# basebid  70  click  129
# basebid  80  click  130
# basebid  90  click  133
# basebid  100  click  139
# basebid  110  click  142
# basebid  120  click  145
# basebid  130  click  146
# basebid  140  click  148
# basebid  150  click  148
# basebid  160  click  150
# basebid  170  click  151
# basebid  180  click  151
# basebid  190  click  151

# %%
base_bids = np.arange(200,300,10)
for counter in base_bids:
    base_bid=counter
    bidprice=bid_linear(base_bid, xx, aCTR)
    print('basebid ', base_bid, ' click ', evaluate(bidprice))
# Out:
# basebid  200  click  152
# basebid  210  click  155
# basebid  220  click  156
# basebid  230  click  159
# basebid  240  click  160
# basebid  250  click  160
# basebid  260  click  158
# basebid  270  click  154
# basebid  280  click  148
# basebid  290  click  145

# %%
# parameters
total_budget = 6250000
payprice = df_valid['payprice'].as_matrix()
Train_df_qr = df_valid.copy()
test_predictions=test_result['click_pred_per']
#test_predictions2=test_result['click_pred_LR']

avgCTR = 1793/2430981 #train set
#tuning...

# %%
def generate_bidprice(base_bid, test_predictions):
    avgCTR = 1793/2430981#train set
    bidprices = base_bid*test_predictions/avgCTR
    return bidprices

# %%
def Prob3(Train_df,payprice,base_bid,test_predictions):
    Train_Const_summ = pd.DataFrame({'Clicks':'', 'Spend':'', 'CTR':'', 'CPM':'', 'eCPC':''}, index=[0])
    
    current_budget = total_budget
    Train_df['win'] = 0 #initialize win label
    bidprices = generate_bidprice(base_bid, test_predictions)
    #start biding...
    for i in Train_df.index:
        if current_budget >= bidprices[i]:
            #generate bidprice:
            current_bidprice = bidprices[i]

            #Winning criterion:
            current_payprice = payprice[i]
            if current_bidprice > current_payprice:
                Train_df.at[i, 'win'] = int(1)
                current_budget = current_budget - current_payprice
            else:
                Train_df.at[i, 'win'] = int(0)
        else:
            print('lack of budget!',current_budget)
            break
    #biding end        
    
    Train_df_new = Train_df[Train_df['win']!=0]
    #wintimes,_ = Train_df_new.shape
    #print('wintimes:',wintimes)
    #print('current_budget',current_budget)

    Clk = Train_df_new['click'].sum()
    Imp = Train_df_new['click'].count()
    CTR = Clk/Imp
    Spd = total_budget - current_budget
    CPM = 1000*Spd/Imp
    eCPC = Spd/Clk
    
    Train_Const_summ.loc[0,'Clicks']=Clk
    Train_Const_summ.loc[0,'Spend']=Spd
    Train_Const_summ.loc[0,'CTR']=CTR
    Train_Const_summ.loc[0,'CPM']=CPM
    Train_Const_summ.loc[0,'eCPC']=eCPC

    print(Train_Const_summ)
    
        
    return Train_df,current_budget

# %%
def calculate_click(base_bid,Train_df,payprice,test_predictions):
    print('base_bid:',base_bid)
    result_df,current_budget = Prob3(Train_df,payprice,base_bid,test_predictions)
    print('current_budget:',current_budget)
    Train_df_new = result_df[result_df['win']!=0]
    wintimes,_ = Train_df_new.shape
    print('wintimes:',wintimes)
    print('----------------')
    Clk = Train_df_new['click'].sum()    
    return Clk

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import mpld3
import numpy as np

# %%
base_bids = np.arange(245,250,1)
Clks = [calculate_click(base_bid,Train_df_qr,payprice,test_predictions) for base_bid in base_bids]
fig = plt.figure()
print(max(Clks))
plt.plot(base_bids,Clks)
mpld3.display(fig)
# Out:
# base_bid: 245
#        CPM         CTR Clicks    Spend     eCPC
# 0  57670.7  0.00151166    160  6104095  38150.6
# current_budget: 145905
# wintimes: 105844
# ----------------
# base_bid: 246
#        CPM         CTR Clicks    Spend     eCPC
# 0  57713.6  0.00150888    160  6119892  38249.3
# current_budget: 130108
# wintimes: 106039
# ----------------
# base_bid: 247
#        CPM         CTR Clicks    Spend     eCPC
# 0  57763.5  0.00150595    160  6137087  38356.8
# current_budget: 112913
# wintimes: 106245
# ----------------
# base_bid: 248
#        CPM         CTR Clicks    Spend     eCPC
# 0  57811.4  0.00150283    160  6154945  38468.4
# current_budget: 95055
# wintimes: 106466
# ----------------
# base_bid: 249
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-e8b6da10bf6b> in <module>()
#       1 base_bids = np.arange(245,250,1)
# ----> 2 Clks = [calculate_click(base_bid,Train_df_qr,payprice,test_predictions) for base_bid in base_bids]
#       3 fig = plt.figure()
#       4 print(max(Clks))
#       5 plt.plot(base_bids,Clks)
#
# <ipython-input-58-e8b6da10bf6b> in <listcomp>(.0)
#       1 base_bids = np.arange(245,250,1)
# ----> 2 Clks = [calculate_click(base_bid,Train_df_qr,payprice,test_predictions) for base_bid in base_bids]
#       3 fig = plt.figure()
#       4 print(max(Clks))
#       5 plt.plot(base_bids,Clks)
#
# <ipython-input-50-7e1d6cf6c1ea> in calculate_click(base_bid, Train_df, payprice, test_predictions)
#       1 def calculate_click(base_bid,Train_df,payprice,test_predictions):
#       2     print('base_bid:',base_bid)
# ----> 3     result_df,current_budget = Prob3(Train_df,payprice,base_bid,test_predictions)
#       4     print('current_budget:',current_budget)
#       5     Train_df_new = result_df[result_df['win']!=0]
#
# <ipython-input-49-04e7dbf11205> in Prob3(Train_df, payprice, base_bid, test_predictions)
#       7     #start biding...
#       8     for i in Train_df.index:
# ----> 9         if current_budget >= bidprices[i]:
#      10             #generate bidprice:
#      11             current_bidprice = bidprices[i]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Different optimizers

# %%
# %pylab inline
for optim, title in [(tf.train.AdamOptimizer(learning_rate=0.001), 'Adam'), 
              (tf.train.FtrlOptimizer(0.01, l1_regularization_strength=0.01), 'FTRL')]:
    acc = []
    model = TFFMClassifier(
        order=3, 
        rank=10, 
        optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
        n_epochs=30, 
        batch_size=1024,
        init_std=0.001,
        reg=0.01,
        input_type='sparse',
        seed=42
    )
    n_epochs = 5
    anchor_epochs = range(0, 200+1, n_epochs)
    for _ in anchor_epochs:
        # score result every 5 epochs
        model.fit(X_tr_sparse, y_tr, n_epochs=n_epochs, show_progress=True)
        predictions = model.predict(X_te_sparse)
        acc.append(accuracy_score(y_te, predictions))
    plot(anchor_epochs, acc, label=title)
    model.destroy()
xlabel('n_epochs')
ylabel('accuracy')
legend()
grid()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/weisihan/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['title']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.58s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.68s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.67s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.68s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.68s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.64s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.70s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.63s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.63s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.63s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.59s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.67s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.54s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.50s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.52s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.48s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.47s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.46s/epoch]

# %%
# %pylab inline
for optim, title in [(tf.train.AdamOptimizer(learning_rate=0.001), 'Adam'), 
              (tf.train.FtrlOptimizer(0.01, l1_regularization_strength=0.01), 'FTRL')]:
    acc = []
    model = TFFMClassifier(
        order=3, 
        rank=10, 
        optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
        n_epochs=30, 
        batch_size=1024,
        init_std=0.001,
        reg=0.01,
        input_type='sparse',
        seed=42
    )
    n_epochs = 5
    anchor_epochs = range(0, 200+1, n_epochs)
    for _ in anchor_epochs:
        # score result every 5 epochs
        model.fit(X_tr_sparse, y_tr, n_epochs=n_epochs, show_progress=True)
        predictions = model.predict_proba(X_te_sparse)
        acc.append(roc_auc_score(y_te, predictions[:,1]))
    plot(anchor_epochs, acc, label=title)
    model.destroy()
xlabel('n_epochs')
ylabel('auc')
legend()
grid()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/weisihan/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['title']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# 100%|██████████| 5/5 [00:08<00:00,  1.75s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.97s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.84s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.82s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.70s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.99s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.78s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.81s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.87s/epoch]
# 100%|██████████| 5/5 [00:10<00:00,  2.10s/epoch]
# /Users/weisihan/Downloads/tffm-master/tffm/utils.py:195: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# 100%|██████████| 5/5 [00:11<00:00,  2.26s/epoch]
# 100%|██████████| 5/5 [00:11<00:00,  2.33s/epoch]
# 100%|██████████| 5/5 [00:10<00:00,  2.07s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.85s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.91s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.78s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.84s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.92s/epoch]
# 100%|██████████| 5/5 [00:11<00:00,  2.26s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.88s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.73s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.90s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.78s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.58s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.95s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.71s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.77s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.64s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.68s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.64s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.59s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.59s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.58s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.58s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.85s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.90s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.72s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.59s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.80s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.69s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.68s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.67s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.60s/epoch]
# 100%|██████████| 5/5 [00:09<00:00,  1.91s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.62s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/epoch]
# 100%|██████████| 5/5 [00:07<00:00,  1.56s/epoch]
# 100%|██████████| 5/5 [00:10<00:00,  2.01s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.80s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.60s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/epoch]
# 100%|██████████| 5/5 [00:10<00:00,  2.02s/epoch]
# 100%|██████████| 5/5 [00:11<00:00,  2.39s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.71s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.63s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.74s/epoch]
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/epoch]
